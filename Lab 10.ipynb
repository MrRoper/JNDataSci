# %%
import pandas as pd
from bokeh.charts import BoxPlot, Scatter, show

auto = pd.read_csv("Automobile_price_data _clean.csv")
autoND = pd.read_csv("Automobile_price_data _NoDash.csv")

# %%
auto.head()
# Out:
#         make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 0      honda       gas        std          two  hatchback          fwd
# 1  chevrolet       gas        std          two  hatchback          fwd
# 2     nissan    diesel        std          two      sedan          fwd
# 3     toyota    diesel        std         four  hatchback          fwd
# 4     toyota       gas        std         four      sedan          fwd
#
#   engine-location  wheel-base  length  width  ...    engine-size  fuel-system  \
# 0           front        86.6   144.6   63.9  ...             92         1bbl
# 1           front        88.4   141.1   60.3  ...             61         2bbl
# 2           front        94.5   165.3   63.8  ...            103          idi
# 3           front        95.7   166.3   64.4  ...            110          idi
# 4           front        95.7   166.3   64.4  ...             98         2bbl
#
#    bore stroke  compression-ratio horsepower peak-rpm city-mpg  highway-mpg  \
# 0  2.91   3.41                9.6         58     4800       49           54
# 1  2.91   3.03                9.5         48     5100       47           53
# 2  2.99   3.47               21.9         55     4800       45           50
# 3  3.27   3.35               22.5         56     4500       38           47
# 4  3.19   3.03                9.0         70     4800       38           47
#
#    price
# 0   6479
# 1   5151
# 2   7099
# 3   7788
# 4   7738
#
# [5 rows x 24 columns]

# %%
autoND.head()
# Out:
#         make fueltype aspiration numofdoors  bodystyle drivewheels  \
# 0      honda      gas        std        two  hatchback         fwd
# 1  chevrolet      gas        std        two  hatchback         fwd
# 2     nissan   diesel        std        two      sedan         fwd
# 3     toyota   diesel        std       four  hatchback         fwd
# 4     toyota      gas        std       four      sedan         fwd
#
#   enginelocation  wheelbase  length  width  ...    enginesize  fuelsystem  \
# 0          front       86.6   144.6   63.9  ...            92        1bbl
# 1          front       88.4   141.1   60.3  ...            61        2bbl
# 2          front       94.5   165.3   63.8  ...           103         idi
# 3          front       95.7   166.3   64.4  ...           110         idi
# 4          front       95.7   166.3   64.4  ...            98        2bbl
#
#    bore stroke  compressionratio horsepower peakrpm citympg  highwaympg  price
# 0  2.91   3.41               9.6         58    4800      49          54   6479
# 1  2.91   3.03               9.5         48    5100      47          53   5151
# 2  2.99   3.47              21.9         55    4800      45          50   7099
# 3  3.27   3.35              22.5         56    4500      38          47   7788
# 4  3.19   3.03               9.0         70    4800      38          47   7738
#
# [5 rows x 24 columns]

# %%
p = BoxPlot(auto, values = "price", label = ["make", "body-style"], color = "make", plot_width = 800, plot_height = 600, title = "Price Summary (grouped by make,body-style)")
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f3f751c9-b958-46e4-96dd-53d3cfab6902">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="28e0df3f-82aa-45b9-934c-1e2f0cb2f3ff"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("28e0df3f-82aa-45b9-934c-1e2f0cb2f3ff").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("28e0df3f-82aa-45b9-934c-1e2f0cb2f3ff");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid
","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"46dba546-7c37-4a02-88d8-3eb103863aa4","type":"GlyphRenderer"},{"attributes":{"label":{"value":"('peugot', 'sedan')"},"renderers":[{"id":"84a90c74-4e6f-4b1d-85ef-69c9cca7476d","type":"GlyphRenderer"},{"id":"0afaaabf-39d7-4e47-b5ab-62985fdc0cb2","type":"GlyphRenderer"},{"id":"d7020018-bc70-47d9-85d7-f936a5e6cedf","type":"GlyphRenderer"}]},"id":"9e681745-29e1-47fd-be35-8b6183f9b62d","type":"LegendItem"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"c179f668-4919-40d3-b45c-0afe8cf26ccf","type":"Segment"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8964bf0d-0e16-4317-9450-f52a52991245","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x ...

# %% [markdown]
# The above line is supposed to produce a graph but GitHub is not able to show it. These differ from seaborn and matplotlib graphs because they are interactive.
# You can view the graph here: http://htmlpreview.github.io/?https://github.com/MrRoper/JNDataSci/blob/master/Lab10%20First%20Graph.html

# %%
tooltips=[
  ('Price', '@price'),
  ('Make', '@make'),
  ('Body-style', '@bodystyle'),
  ('City-mpg', '@citympg'),    
]

p2 = Scatter(autoND, x = "citympg", y = "price", color = "make", marker = "bodystyle", title = "LAS350A - Lab 10: Price vs City-mpg (shaded by Make, maker by Body-style)", plot_width = 800, plot_height = 600, tooltips=tooltips)
show(p2)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="32ae66d3-8772-471d-b4b3-a41610919d4b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c2e13631-e875-46b0-a73c-c43e877874b7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c2e13631-e875-46b0-a73c-c43e877874b7").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c2e13631-e875-46b0-a73c-c43e877874b7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c2e13631-e875-46b0-a73c-c43e877874b7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6dd03dcf-9458-4ec1-bc6e-247df83a630e":{"roots":{"references":[{"attributes":{"data_source":{"id":"5b07729e-b6ea-4b83-a770-0175b90b9688","type":"ColumnDataSource"},"glyph":{"id":"62127b53-a877-4544-9419-1673fddf5880","type":"InvertedTriangle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e42ec10e-732e-455d-9988-2b5dbecc043a","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#df5320"},"line_color":{"value":"#df5320"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"62127b53-a877-4544-9419-1673fddf5880","type":"InvertedTriangle"},{"attributes":{"callback":null,"column_names":["x_values","y_values","price","citympg"],"data":{"bodystyle":["wagon"],"chart_index":[{"bodystyle":"wagon","make":"mercedes-benz"}],"citympg":[22],"make":["mercedes-benz"],"price":[28248],"x_values":[22],"y_values":[28248]}},"id":"5b07729e-b6ea-4b83-a770-0175b90b9688","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":52.6,"start":9.4},"id":"a8898043-41be-4faa-97bd-215ecd40a933","type":"Range1d"},{"attributes":{"data_source":{"id":"3f9fc004-794e-458a-9060-153db47d5e0e","type":"ColumnDataSource"},"glyph":{"id":"2bdae026-ae72-4694-8bed-c7f2380d6686","type":"InvertedTriangle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"910f2865-b2df-4ba1-a5e5-aba107047769","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"2bdae026-ae72-4694-8bed-c7f2380d6686","type":"InvertedTriangle"},{"attributes":{"callback":null,"column_names":["x_values","y_values","price","citympg"],"data":{"bodystyle":["wagon"],"chart_index":[{"bodystyle":"wagon","make":"audi"}],"citympg":[19],"make":["audi"],"price":[18920],"x_values":[19],"y_values":[18920]}},"id":"3f9fc004-794e-458a-9060-153db47d5e0e","type":"ColumnDataSource"},{"attributes":{"axis_label":"citympg","formatter":{"id":"898f4c84-73d9-438e-bb01-d6c517be6f99","type":"BasicTickFormatter"},"plot":{"id":"f2025adc-4f36-4e83-bd79-99d2d89ad694","subtype":"Chart","type":"Plot"},"ticker":{"id":"519c5a49-6dd7-4a89-8c14-24d1a7a25f2d","type":"BasicTicker"}},"id":"647190e9-86b2-409c-889e-5cbb134e3000","type":"LinearAxis"},{"attributes":{"items":[{"id":"f9784817-91de-4e1f-a3af-5666c4af5ea1","type":"LegendItem"},{"id":"f3a14d16-5e5e-4497-9edc-826dfeed46db","type":"LegendItem"},{"id":"afbe7694-6b44-4d7b-83b0-49755c6ce095","type":"LegendItem"},{"id":"d9206b5a-b5c2-46e0-99e7-13c6d52f7cb1","type":"LegendItem"},{"id":"a9fdada8-b7ab-4a00-94ac-e2596b8f6a64","type":"LegendItem"},{"id":"e60d1bb3-d24b-4965-97b4-1f84bde1a306","type":"LegendItem"},{"id":"4f3b65d8-997e-4028-b7fb-cadfdb97d314","type":"LegendItem"},{"id":"80549b51-2fdc-41c9-861f-904cd13fb44b","type":"LegendItem"},{"id":"aa9e86bf-115c-4e4d-920b-a12ea9375f8e","type":"LegendItem"},{"id":"5832b34e-60c0-47c0-a0d5-6d1e1a7a97d2","type":"LegendItem"},{"id":"664bb1aa-3018-4609-afd1-3f8fe8270f8b","type":"LegendItem"},{"id":"99e02327-7306-4db5-a2e8-e14f364762d0","type":"LegendItem"},{"id":"6589328f-4f85-462a-b665-5f444c71dabe","type":"LegendItem"},{"id":"39b000c4-ed8f-407b-bade-f724b29629a2","type":"LegendItem"},{"id":"0f73ab35-5876-44d9-a0f0-9c3236ca4670","type":"LegendItem"},{"id":"3e49a6bf-ece8-439d-95a9-1c3d93a8b089","type":"LegendItem"},{"id":"cfcb819c-7c8d-418c-8d8c-54705fd82a8f","type":"LegendItem"},{"id":"cb27d97c-f4d7-4b98-9081-917e8eb75d32","type":"LegendItem"},{"id":"6c7fccdf-a26d-4dca-8da2-6158bf528325","type":"LegendItem"},{"id":"3e4e29e3-ea19-46fd-9cbc-f57fb5efcd63","type":"LegendItem"},{"id":"cde73794-e24f-4b8c-8131-4bd387d2c703","type":"LegendItem"},{"id":"58047e60-9e14-4d51-933a-2c109da5ecb0","type":"LegendItem"},{"id":"b7a06938-dc4b-42a6-8151-6171f35d5b71","type":"LegendItem"},{"id":"47173f9e-c3a1-4c48-bda3-1a757c377ab1","type":"LegendIte ...

# %% [markdown]
# Same thing as the first one. The only difference is this one has tooltips.
# You can view the graph here: http://htmlpreview.github.io/?https://github.com/MrRoper/JNDataSci/blob/master/Lab10%20Second%20Graph.html

# %% [markdown]
# The most efficient city-mpg sedan is a Nissan. It has a city mpg of 45 and a price of 7099.
