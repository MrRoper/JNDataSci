# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline

auto = pd.read_csv('automobile_price_data _Raw.csv')

# %%
auto.boxplot(column='engine-size', by='make', figsize = (15,10), fontsize=15, rot=45)

# %%
auto.boxplot(column='price', by='make', figsize = (15,10), fontsize=15, rot=45)
# This is showing an error because not every entry in the price column is an integer, some are strings. This causes entries in the price column to be considered objects instead of integers.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-78c1876755fc> in <module>()
# ----> 1 auto.boxplot(column='price', by='make', figsize = (15,10), fontsize=15, rot=45)
#       2 # This is showing an error because not every entry in the price column is an integer, some are strings. This causes entries in the price column to be considered objects instead of integers.
#
# C:\Tools\Anaconda\lib\site-packages\pandas\core\frame.py in boxplot(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    5747     ax = plots.boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    5748                        grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 5749                        return_type=return_type, **kwds)
#    5750     plt.draw_if_interactive()
#    5751     return ax
#
# ...

# %%
auto.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
auto_clean = pd.read_csv('Automobile_price_data _clean.csv')

# %%
auto_clean.dtypes
# Out:
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower             int64
# peak-rpm               int64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
auto_clean.boxplot(column='price', by='make', figsize = (15,10), fontsize=15, rot=45)

# %%
sns.pairplot(auto_clean, hue = "make", size = 2.5);

# %%
sns.pairplot(auto_clean.loc[:,["city-mpg", "highway-mpg", "curb-weight", "make", "engine-size", "price", "horsepower"]], hue = "make");
